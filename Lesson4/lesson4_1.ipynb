# %% [markdown]
# ### 11/23 Module
#
# 1. 內部套件 * 說明 / 前面全部要使用引數值呼叫  ＊後面要用引數名稱呼叫
# 2. 外部套件 pypi套件索引
# 3. 自訂的Function
#     - 主程式變簡單
#     - 可重複呼叫
#     - 可簡化

# %% [markdown]
# #### 專案檔組成
#     - 命名空間 main_
